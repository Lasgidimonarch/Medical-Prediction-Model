# %% [markdown]
# <div class="hover-effect" id="setup">
#         <p class="text"><b>👨🏻‍⚕️ Health Charges Prediction 🩺</b></p>
#         <div class="overlay"></div>
# </div>

# %% [markdown]
# <a id="contents_table"></a>
#
# <div style="background-color:##21b1d6; padding: 20px; border-radius: 15px; box-shadow: 0 2px 4px 0 rgba(0, 0, 0, 0.1);">
#     <h1 style="font-size:24px; font-family:calibri; color:#6495ed;"><b>👨🏻‍⚕ Table of Contents 🩺</b></h1>
#     <ul style="font-size:20px; font-family:calibri; line-height: 1.5em;">
#         <li><a href="#libraries" style="text-decoration: none;font-size:16px;">Step 1 | Import Libraries</a></li>
#         <li><a href="#read" style="text-decoration: none;font-size:16px;">Step 2 | Read Dataset</a>
#         </li>
#         <li><a href="#overview" style="text-decoration: none;font-size:16px;">Step 3 | Dataset Overview & Preparation</a>
#             <ul>
#                 <li><a href="#description" style="text-decoration: none;font-size:14px;">Step 3.1 | Description Of Variables</a></li>
#                 <li><a href="#review" style="text-decoration: none;font-size:14px;">Step 3.2 | Quick Review Of Dataset</a></li>
#                 <li><a href="#info" style="text-decoration: none;font-size:14px;">Step 3.3 | Basic Information</a></li>
#                 <li><a href="#summary" style="text-decoration: none;font-size:14px;">Step 3.4 | Rename Variables</a></li>
#                  <li><a href="#summary" style="text-decoration: none;font-size:14px;">Step 3.5 | Statistical Summary</a></li>
#             </ul>
#         </li>
#         <li><a href="#eda" style="text-decoration: none;font-size:16px;">Step 4 | Exploratary Data Analysis (EDA)</a>
#             <ul>
#                 <li><a href="#univariate" style="text-decoration: none;font-size:14px;">Step 4.1 | Univariate Analysis</a></li>
#                 <ul>
#                     <li><a href="#numerical_univariate" style="text-decoration: none;font-size:13px;">Step 4.1.1 | Numerical Variables</a></li>
#                     <li><a href="#categorical_univariate" style="text-decoration: none;font-size:13px;">Step 4.1.2 | Binary & Categorical Variables</a></li>
#                 </ul>
#                 <li><a href="#bivariate" style="text-decoration: none;font-size:16px;">Step 4.2 | Bivariate Analysis</a></li>
#                 <ul>
#                     <li><a href="#numerical_bivariate" style="text-decoration: none;font-size:13px;">Step 4.2.1 | Numerical Variables</a></li>
#                     <li><a href="#categorical_bivariate" style="text-decoration: none;font-size:13px;">Step 4.2.2 | Binary & Categorical Variables</a></li>
#                 </ul>
#             </ul>
#         </li>
#         <li><a href="#preprocessing" style="text-decoration: none;font-size:16px;">Step 5 | Preprocessing</a></li>
#         <ul>
#             <li>
#                 <a href="#outliers" style="text-decoration: none;font-size:14px;">Step 5.1 | Handling Outliers</a>
#                 <ul>
#                     <li><a href="#boxcox" style="text-decoration: none;font-size:14px;">5.1.1 | Box-Cox Transformation</a></li>
#                     <li><a href="#nboxcox" style="text-decoration: none;font-size:14px;">5.1.2 | Numerical Variables After Box-Cox Transformation</a></li>
#                 </ul>
#             </li>
#             <li><a href="#missing" style="text-decoration: none;font-size:14px;">Step 5.2 | Missing Values</a></li>
#             <li><a href="#duplicated" style="text-decoration: none;font-size:14px;">Step 5.3 | Duplicated Values</a></li>
#         </ul>
#          <li><a href="#feature_engineering" style="text-decoration: none;font-size:16px;">Step 6 | Feature Engineering</a>
#             <ul>
#                 <li><a href="#onehot_encoding" style="text-decoration: none;font-size:14px;">Step 6.1 | One-Hot Encoding</a></li>
#                 <li><a href="#label_encoding" style="text-decoration: none;font-size:14px;">Step 6.2 | Label Encoding</a></li>
#             </ul>
#         </li>
#         <li><a href="#corr" style="text-decoration: none;font-size:16px;">Step 7 | Correlation Analysis</a></li>
#         <li><a href="#modeling" style="text-decoration: none;font-size:16px;">Step 8 | Modeling</a>
#             <ul>
#                 <li>
#                     <a href="#knn" style="text-decoration: none;font-size:14px;">Step 8.1 | Linear Regression (LN)</a>
#                     <ul>
#                         <li><a href="#knn-hpt" style="text-decoration: none;font-size:13px;"> Step 8.1.1 | Build LN & Hyper-parameter tuning</a></li>
#                         <li><a href="#knn-evaluation" style="text-decoration: none;font-size:13px;"> Step 8.1.2 | LN Model Evaluation </a></li>
#                     </ul>
#                 </li>
#                 <li>
#                     <a href="#svm" style="text-decoration: none;font-size:14px;">Step 8.2 | Support Vector Machine (SVM)</a>
#                     <ul>
#                         <li><a href="#svm-hpt" style="text-decoration: none;font-size:13px;"> Step 8.2.1 | Build SVM &  Hyper-parameter Tuning</a></li>
#                         <li><a href="#svm-evaluation" style="text-decoration: none;font-size:13px;"> Step 8.2.2 | SVM Model Evaluation </a></li>
#                     </ul>
#                 </li>
#                 <li>
#                     <a href="#dts" style="text-decoration: none;font-size:14px;">Step 8.3 | Gradient Boosting (GB)</a>
#                     <ul>
#                         <li><a href="#dts-hpt" style="text-decoration: none;font-size:13px;"> Step 8.3.1 | Build GB & Hyper-parameter tuning</a></li>
#                         <li><a href="#dts-evaluation" style="text-decoration: none;font-size:13px;"> Step 8.3.2 | GB Model Evaluation </a></li>
#                     </ul>
#                 </li>
#                 <li>
#                     <a href="#rf" style="text-decoration: none;font-size:14px;">Step 8.4 | Random Forest (RF)</a>
#                     <ul>
#                         <li><a href="#rf-hpt" style="text-decoration: none;font-size:13px;"> Step 8.4.1 | Build RF & Hyper-parameter tuning</a></li>
#                         <li><a href="#rf-evaluation" style="text-decoration: none;font-size:13px;"> Step 8.4.2 | RF Model Evaluation </a></li>
#                     </ul>
#                 </li>
#                  <li>
#                     <a href="#rf" style="text-decoration: none;font-size:14px;">Step 8.5 | Ridge Model (RM)</a>
#                     <ul>
#                         <li><a href="#rf-hpt" style="text-decoration: none;font-size:13px;"> Step 8.5.1 | Build RM & Hyper-parameter tuning</a></li>
#                         <li><a href="#rf-evaluation" style="text-decoration: none;font-size:13px;"> Step 8.5.2 | RM Model Evaluation </a></li>
#                     </ul>
#                 </li>
#                   <li>
#                     <a href="#rf" style="text-decoration: none;font-size:14px;">Step 8.6 | Lasso Regression (LR)</a>
#                     <ul>
#                         <li><a href="#rf-hpt" style="text-decoration: none;font-size:13px;"> Step 8.6.1 | Build LR & Hyper-parameter tuning</a></li>
#                         <li><a href="#rf-evaluation" style="text-decoration: none;font-size:13px;"> Step 8.6.2 | LR Model Evaluation </a></li>
#                     </ul>
#                 </li>
#                 </ul>
#                 </li>
#         <li><a href="#conclusion" style="text-decoration: none;font-size:16px;">Step 10 | Conclusion</a></li>
#         <li><a href="#communication" style="text-decoration: none;font-size:16px;">Communications</a></li>
#     </ul>
# </div>

# %% [markdown]
# <div class="hover-effect" id="libraries">
#         <p class="text"><b>👨🏻‍⚕️ Step 1 | Import Libraries</b></p>
# <div class="overlay"></div>
# </div>

# %%
# Data Manipulation
import numpy as np
import pandas as pd

# Visualizations
import seaborn as sns
import matplotlib.pyplot as plt 
from scipy.stats import boxcox

# Model libraries
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix, roc_curve, roc_auc_score
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score 
from math import sqrt
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import accuracy_score, classification_report
from sklearn.linear_model import Ridge
from sklearn.ensemble import GradientBoostingRegressor
from sklearn import svm
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import Lasso
# Ignore warnings
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# <a id="read"></a>
# <div class="hover-effect" id="setup">
#         <p class="text"><b>👨🏻‍⚕️ Step 2 | Read Dataset</b></p>
#         <div class="overlay"></div>
# </div>

# %%
df = pd.read_csv(r"C:\Users\LasgidiMonarch\Documents\lare\insurance.csv")

# %%
df.dtypes
# Out:
# age           int64
# sex          object
# bmi         float64
# children      int64
# smoker       object
# region       object
# charges     float64
# dtype: object

# %% [markdown]
# <a id="description"></a>
# <b><span style='color:#21b1d6; font-size:20px;'>Step 3.1 |</span><span style='color:#2195ed;font-size:20px;'> Description Of Variables</span></b>

# %% [markdown]
# <div style="background-color:#21b1d6; padding: 20px; border-radius: 15px; box-shadow: 0 2px 4px 0 #f0f8ff;">
#     <p style="font-size:16px; font-family:Calibri, sans-serif; line-height: 1.5em; text-align: justify; color: #f0f8ff">
#         I provided a description of each variable in the dataset below:
#     </p>
# </div>

# %% [markdown]
# <div style="padding:0px; font-size:7px; border-radius: 10px;">
#     <table style="width: 100%; background-color:#f0f8ff;">
#         <tr>
#             <th style="text-align:center;font-size:20px;"><b>Variable</b></th>
#             <th style="text-align:center;font-size:20px;"><b>Description</b></th>
#             <th style="text-align:center;font-size:20px;"><b>Data Type</b></th>
#         </tr>
#         <tr>
#             <td style="text-align:center; color:#0f52ba;font-size:15px;"><strong>Age</strong></td>
#             <td style="text-align:center; color:#0f52ba;font-size:15px;">Age of the patient in years</td>
#             <td style="text-align:center;color:#0f52ba;font-size:15px;">Numeric</td>
#         </tr>
#         <tr>
#             <td style="text-align:center;color:#0f52ba;font-size:15px;"><strong>Sex</strong></td>
#             <td style="text-align:center;color:#0f52ba;font-size:15px;">Gender of the patient:<br>0: female<br>1: male</td>
#             <td style="text-align:center;color:#0f52ba;font-size:15px;">Object</td>
#         </tr>
#         <tr>
#             <td style="text-align:center;color:#0f52ba;font-size:15px;"><strong>Bmi</strong></td>
#             <td style="text-align:center;color:#0f52ba;font-size:15px;">Body weight in kg/m2<sup>2</sup>:<br>1: Underweight(Below 18.5)<br>2: Healthy Weight (18.5 - 24.9)<br>3: Overweight (25.0 - 29.9)<br>:4 Obesity (30.0 and above)</td>
#             <td style="text-align:center;color:#0f52ba;font-size:15px;">Float</td>
#         </tr>
#         <tr>
#             <td style="text-align:center;color:#0f52ba;font-size:15px;"><strong>Children</strong></td>
#             <td style="text-align:center;color:#0f52ba;font-size:15px;">Number of Children</td>
#             <td style="text-align:center;color:#0f52ba;font-size:15px;">Numeric</td>
#         </tr>
#         <tr>
#             <td style="text-align:center;color:#0f52ba;font-size:15px;"><strong>Smoker</strong></td>
#             <td style="text-align:center;color:#0f52ba;font-size:15px;">No of Smokers</td>
#             <td style="text-align:center;color:#0f52ba;font-size:15px;">Numeric</td>
#         </tr>
#         <tr>
#             <td style="text-align:center;color:#0f52ba;font-size:15px;"><strong>Region</strong></td>
#             <td style="text-align:center;color:#0f52ba;font-size:15px;">Regions of Patients:<br>1: Southwest<br>2: Southeast<br>3: Northwest<br>4: Northeast</td>
#             <td style="text-align:center;color:#0f52ba;font-size:15px;">Object</td>
#         </tr>
#         <tr>
#             <td style="text-align:center;color:#0f52ba;font-size:15px;"><strong>Charges</strong></td>
#             <td style="text-align:center;color:#0f52ba;font-size:15px;">Charges of each Patient</td>
#             <td style="text-align:center;color:#0f52ba;font-size:15px;">Numerical</td>
#         </tr>
#         <tr>
#     </table>
# </div>

# %% [markdown]
# <a id="rename"></a>
# <b><span style='color:#21b1d6; font-size:20px;'>Step 3.2 |</span><span style='color:#6495ed;font-size:20px;'> Rename Variables</span></b>

# %%
df.rename(columns={
    "age":"Age",
    "sex":"Sex",
    "bmi":"Body weight in kg/m2",
    "children":"Children",
    "smoker":"Smoker",
    "region":"Regions",
    "charges":"Charges"
}, inplace=True)

# %%
df.head()
# Out:
#    Age     Sex  Body weight in kg/m2  Children Smoker    Regions      Charges
# 0   19  female                27.900         0    yes  southwest  16884.92400
# 1   18    male                33.770         1     no  southeast   1725.55230
# 2   28    male                33.000         3     no  southeast   4449.46200
# 3   33    male                22.705         0     no  northwest  21984.47061
# 4   32    male                28.880         0     no  northwest   3866.85520

# %% [markdown]
# <div style="background-color:#4169e1; padding: 20px; border-radius: 15px; box-shadow: 0 2px 4px 0 #f0f8ff;">
#     <p style="font-size:16px; font-family:Calibri, sans-serif; line-height: 1.5em; text-align: justify; color: #f0f8ff">
# Conversion of some Categorical values to Integral values
#     </p>
# </div>

# %%
df['Sex'] = df['Sex'].replace({'female': 0, 'male': 1})
df['Smoker'] = df['Smoker'].replace({'no': 0, 'yes': 1})
df['Regions'] = df['Regions'].replace({'southwest': 1, 'southeast': 2, 'northwest': 3, 'northeast': 4 })

# %%
df.nunique()
# Out:
# Age                       47
# Sex                        2
# Body weight in kg/m2     548
# Children                   6
# Smoker                     2
# Regions                    4
# Charges                 1337
# dtype: int64

# %% [markdown]
# <a id="review"></a>
# <b><span style='color:#45b1e8; font-size:20px;'>Step 3.3 |</span><span style='color:#6495ed;font-size:20px;'> Quick Review Of Dataset</span></b>

# %% [markdown]
# <div style="background-color:#4169e1; padding: 1px; border-radius: 15px; box-shadow: 0 2px 4px 0 #f0f8ff;">
#     <p style="font-size:20px; font-family:Calibri, sans-serif; line-height: 1.5em; text-align: justify; text-indent: 20px;color: #f0f8ff;">
# First 5 samples
#     </p>
# </div>

# %%
df.head()
# Out:
#    Age  Sex  Body weight in kg/m2  Children  Smoker  Regions      Charges
# 0   19    0                27.900         0       1        1  16884.92400
# 1   18    1                33.770         1       0        2   1725.55230
# 2   28    1                33.000         3       0        2   4449.46200
# 3   33    1                22.705         0       0        3  21984.47061
# 4   32    1                28.880         0       0        3   3866.85520

# %% [markdown]
# <div style="background-color:#4169e1; padding: 1px; border-radius: 15px; box-shadow: 0 2px 4px 0 #f0f8ff;">
#     <p style="font-size:20px; font-family:Calibri, sans-serif; line-height: 1.5em; text-align: justify; text-indent: 20px;color: #f0f8ff;">
# Last 5 samples
#     </p>
# </div>

# %%
df.tail()
# Out:
#       Age  Sex  Body weight in kg/m2  Children  Smoker  Regions     Charges
# 1333   50    1                 30.97         3       0        3  10600.5483
# 1334   18    0                 31.92         0       0        4   2205.9808
# 1335   18    0                 36.85         0       0        2   1629.8335
# 1336   21    0                 25.80         0       0        1   2007.9450
# 1337   61    0                 29.07         0       1        3  29141.3603

# %%
df.shape
# Out:
# (1338, 7)

# %% [markdown]
# <div style="background-color:#f0f8ff; padding: 20px; border-radius: 15px; box-shadow: 0 2px 4px 0 #f0f8ff;">
# <p style="font-size:16px; font-family:Calibri, sans-serif; line-height: 1.5em; text-indent: 20px;text-align: justify; color:#0f52ba;">
# This dataset has <b>1338</b> samples and <b>7</b> variables
# </p>

# %% [markdown]
# <a id="info"></a>
# <b><span style='color:#45b1e8; font-size:20px;'>Step 3.4 |</span><span style='color:#6495ed;font-size:20px;'> Basic Information</span></b>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Age                   1338 non-null   int64
#  1   Sex                   1338 non-null   int64
#  2   Body weight in kg/m2  1338 non-null   float64
#  3   Children              1338 non-null   int64
#  4   Smoker                1338 non-null   int64
#  5   Regions               1338 non-null   int64
#  6   Charges               1338 non-null   float64
# dtypes: float64(2), int64(5)
# memory usage: 73.3 KB

# %% [markdown]
# <a id="info"></a>
# <b><span style='color:#45b1e8; font-size:20px;'>Step 3.4 |</span><span style='color:#6495ed;font-size:20px;'> Statistical Summary</span></b>

# %%
df_stats = df.copy()

# %%
df_stats.describe().T
# Out:
#                        count          mean           std        min  \
# Age                   1338.0     39.207025     14.049960    18.0000
# Sex                   1338.0      0.505232      0.500160     0.0000
# Body weight in kg/m2  1338.0     30.663397      6.098187    15.9600
# Children              1338.0      1.094918      1.205493     0.0000
# Smoker                1338.0      0.204783      0.403694     0.0000
# Regions               1338.0      2.484305      1.104885     1.0000
# Charges               1338.0  13270.422265  12110.011237  1121.8739
#
#                              25%       50%           75%          max
# Age                     27.00000    39.000     51.000000     64.00000
# Sex                      0.00000     1.000      1.000000      1.00000
# Body weight in kg/m2    26.29625    30.400     34.693750     53.13000
# Children                 0.00000     1.000      2.000000      5.00000
# Smoker                   0.00000     0.000      0.000000      1.00000
# Regions                  2.00000     2.000      3.000000      4.00000
# Charges               4740.28715  9382.033  16639.912515  63770.42801

# %% [markdown]
# <a id="eda"></a>
# <div class="hover-effect" id="setup">
#         <p class="text"><b>👨🏻‍⚕️ Step 4 | Exploratary Data Analysis (EDA)</b></p>
#         <div class="overlay"></div>
# </div>

# %% [markdown]
# <div style="background-color:#4169e1; padding: 1px; border-radius: 15px; box-shadow: 0 2px 4px 0 #f0f8ff;">
#     <p style="font-size:20px; font-family:Calibri, sans-serif; line-height: 1.5em; text-align: justify; text-indent: 20px;color: #f0f8ff;">
# Detecting outliers <b>IQR</b> method:
#     </p>
# </div>

# %%
Q1 = np.percentile(df['Charges'], 25)
Q1
# Out:
# 4740.28715

# %%
Q3 = np.percentile(df['Charges'], 75)
Q3
# Out:
# 16639.912515

# %%
IQR = Q3-Q1
IQR
# Out:
# 11899.625365

# %%
lowerbound = Q1 - 1.5 * IQR
lowerbound
# Out:
# -13109.1508975

# %%
upperbound = Q3 + 1.5 * IQR
upperbound
# Out:
# 34489.350562499996

# %%
df_clean = df[(df['Charges'] >= lowerbound) & (df['Charges'] <= upperbound)]
df_clean
# Out:
#       Age  Sex  Body weight in kg/m2  Children  Smoker  Regions      Charges
# 0      19    0                27.900         0       1        1  16884.92400
# 1      18    1                33.770         1       0        2   1725.55230
# 2      28    1                33.000         3       0        2   4449.46200
# 3      33    1                22.705         0       0        3  21984.47061
# 4      32    1                28.880         0       0        3   3866.85520
# ...   ...  ...                   ...       ...     ...      ...          ...
# 1333   50    1                30.970         3       0        3  10600.54830
# 1334   18    0                31.920         0       0        4   2205.98080
# 1335   18    0                36.850         0       0        2   1629.83350
# 1336   21    0                25.800         0       0        1   2007.94500
# 1337   61    0                29.070         0       1        3  29141.36030
#
# [1199 rows x 7 columns]

# %%
sns.boxplot(data = df, x = 'Charges')
# Out:
# <Axes: xlabel='Charges'>

# %% [markdown]
# <a id="eda"></a>
# <div class="hover-effect" id="setup">
#         <p class="text"><b>👨🏻‍⚕️ Step 5 | Preprocessing</b></p>
#         <div class="overlay"></div>
# </div>

# %% [markdown]
# <div style="background-color:#4169e1; padding: 1px; border-radius: 15px; box-shadow: 0 2px 4px 0 #f0f8ff;">
#     <p style="font-size:20px; font-family:Calibri, sans-serif; line-height: 1.5em; text-align: justify; text-indent: 20px;color: #f0f8ff;">
# Charges Boxplot:
#     </p>
# </div>

# %%
sns.set(style='whitegrid')
f, ax = plt.subplots(1,1, figsize=(12, 8))
ax = sns.distplot(df['Charges'], kde = True, color = 'c')
plt.title('Distribution of Charges')
# Out:
# Text(0.5, 1.0, 'Distribution of Charges')

# %%
df.corr()['Charges'].sort_values()
# Out:
# Regions                 0.006208
# Sex                     0.057292
# Children                0.067998
# Body weight in kg/m2    0.198341
# Age                     0.299008
# Smoker                  0.787251
# Charges                 1.000000
# Name: Charges, dtype: float64

# %% [markdown]
# <div style="background-color:#4169e1; padding: 1px; border-radius: 15px; box-shadow: 0 2px 4px 0 #f0f8ff;">
#     <p style="font-size:20px; font-family:Calibri, sans-serif; line-height: 1.5em; text-align: justify; text-indent: 20px;color: #f0f8ff;">
# Charges by Regions:
#     </p>
# </div>

# %%
# First, group the charges by regions and calculate the sum
charges_by_region = df.groupby('Regions')['Charges'].sum()

# Sort the charges in ascending order
charges_by_region = charges_by_region.sort_values(ascending=True)

# Plotting
f, ax = plt.subplots(1, 1, figsize=(8, 6))
sns.barplot(x=charges_by_region.values, y=charges_by_region.index, palette='Blues', ax=ax)
ax.set_xlabel('Charges')
ax.set_ylabel('Regions')
ax.set_title('Sum of Charges by Region')
plt.show()

# %% [markdown]
# <div style="background-color:#4169e1; padding: 1px; border-radius: 15px; box-shadow: 0 2px 4px 0 #f0f8ff;">
#     <p style="font-size:20px; font-family:Calibri, sans-serif; line-height: 1.5em; text-align: justify; text-indent: 20px;color: #f0f8ff;">
# Charges by Regions and Gender:
#     </p>
# </div>

# %%
f, ax = plt.subplots(1, 1, figsize=(12, 8))
sns.barplot(x='Regions', y='Charges', hue='Sex', data=df, palette='cool', ax=ax)
ax.set_xlabel('Regions')
ax.set_ylabel('Charges')
ax.set_title('Charges by Regions and Gender')
plt.show()

# %% [markdown]
# <p>From the chart above it shows males from the south east region tend to have higher health charges than any other region</p>

# %% [markdown]
# <div style="background-color:#4169e1; padding: 1px; border-radius: 15px; box-shadow: 0 2px 4px 0 #f0f8ff;">
#     <p style="font-size:20px; font-family:Calibri, sans-serif; line-height: 1.5em; text-align: justify; text-indent: 20px;color: #f0f8ff;">
# Charges by Region and Smoking Status:
#     </p>
# </div>

# %%
f, ax = plt.subplots(1, 1, figsize=(12, 8))
sns.barplot(x='Regions', y='Charges', hue='Smoker', data=df, palette='Reds_r', ax=ax)
ax.set_xlabel('Regions')
ax.set_ylabel('Charges')
ax.set_title('Charges by Region and Smoking Status')
plt.show()

# %% [markdown]
# <p> The data illustrated above shows people from the southeastern part have a high numbers of smokers and high health charges</p>

# %% [markdown]
# <div style="background-color:#4169e1; padding: 1px; border-radius: 15px; box-shadow: 0 2px 4px 0 #f0f8ff;">
#     <p style="font-size:20px; font-family:Calibri, sans-serif; line-height: 1.5em; text-align: justify; text-indent: 20px;color: #f0f8ff;">
# Charges by Region and Children:
#     </p>
# </div>

# %%
f, ax = plt.subplots(1, 1, figsize=(12, 8))
sns.barplot(x='Regions', y='Charges', hue='Children', data=df, palette='cool', ax=ax)
ax.set_xlabel('Regions')
ax.set_ylabel('Charges')
ax.set_title('Charges by Region and Children')
plt.show()

# %% [markdown]
# <p> As we can see from these barplots the highest charges due to smoking are still in the Southeast but the lowest are in the Northeast. People in the Southwest generally smoke more than people in the Northeast, but people in the Northeast have higher charges by gender than in the Southwest and Northwest overall. And people with children tend to have higher medical costs overall as well</p>

# %%
ax = sns.lmplot(x = 'Age', y = 'Charges', data=df, hue='Smoker', palette='Set1')
ax = sns.lmplot(x = 'Body weight in kg/m2', y = 'Charges', data=df, hue='Smoker', palette='Set2')
ax = sns.lmplot(x = 'Children', y = 'Charges', data=df, hue='Smoker', palette='Set3')

# %% [markdown]
# <p>Smoking has the highest impact on medical charges, not withstanding that costs are increasing with age, body weight and children. Also people who have children generally smoke less</p>

# %% [markdown]
# <div style="background-color:#4169e1; padding: 1px; border-radius: 15px; box-shadow: 0 2px 4px 0 #f0f8ff;">
#     <p style="font-size:20px; font-family:Calibri, sans-serif; line-height: 1.5em; text-align: justify; text-indent: 20px;color: #f0f8ff;">
# Continious Data Visualization:
#     </p>
# </div>

# %%
cont_cols = ["Age","Sex","Body weight in kg/m2","Children","Smoker","Regions"]

for col in cont_cols:

  # Create a figure and subplots for box plot and distplot
  fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 5))

  # Create seaborn boxplot on the first subplot (distribution overview)
  sns.boxplot(data=df, x=col, ax=ax1)  # data argument provides the DataFrame
  ax1.set_title('{} Distribution (Box Plot)'.format(col))

  # Create seaborn distplot on the second subplot (density distribution)
  sns.distplot(df[col], ax=ax2)
  ax2.set_title('{} Distribution (Distplot)'.format(col))

  plt.show()

# %% [markdown]
# <a id="eda"></a>
# <div class="hover-effect" id="setup">
#         <p class="text"><b>👨🏻‍⚕️ Step 7 | Correlation Analysis </b></p>
#         <div class="overlay"></div>
# </div>

# %%
plt.figure(figsize=(16,8))
corr=df.corr()
sns.heatmap(abs(corr),lw=1,annot=True,cmap="Reds")
plt.show()

# %% [markdown]
# <p>No correlation except with Smokers</p>

# %% [markdown]
# <a id="eda"></a>
# <div class="hover-effect" id="setup">
#         <p class="text"><b>👨🏻‍⚕️ Step 8 | Modelling </b></p>
#         <div class="overlay"></div>
# </div>

# %% [markdown]
# <div style="background-color:#4169e1; padding: 1px; border-radius: 15px; box-shadow: 0 2px 4px 0 #f0f8ff;">
#     <p style="font-size:20px; font-family:Calibri, sans-serif; line-height: 1.5em; text-align: justify; text-indent: 20px;color: #f0f8ff;">
# Linear Regression:
#     </p>
# </div>

# %%
x = df.drop(columns=['Charges'])
y = df['Charges']

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
model = LinearRegression()

# %%
mymodel = model.fit(x_train, y_train)

# %%
mymodel
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)

# %%
rsquared = r2_score(y_test, y_pred)

# %%
rsquared*100
# Out:
# 78.33463107364538

# %% [markdown]
# <div style="background-color:#4169e1; padding: 1px; border-radius: 15px; box-shadow: 0 2px 4px 0 #f0f8ff;">
#     <p style="font-size:20px; font-family:Calibri, sans-serif; line-height: 1.5em; text-align: justify; text-indent: 20px;color: #f0f8ff;">
# Support Vector Machine:
#     </p>
# </div>

# %%
SVM = svm.SVR(kernel = 'linear')

# %%
mymodel2 = SVM.fit(x_train, y_train)

# %%
mymodel2
# Out:
# SVR(kernel='linear')

# %%
y_pred2 = SVM.predict(x_test)

# %%
rsquared = r2_score(y_test, y_pred2)

# %%
rsquared*100
# Out:
# -6.867590520684952

# %% [markdown]
# <div style="background-color:#4169e1; padding: 1px; border-radius: 15px; box-shadow: 0 2px 4px 0 #f0f8ff;">
#     <p style="font-size:20px; font-family:Calibri, sans-serif; line-height: 1.5em; text-align: justify; text-indent: 20px;color: #f0f8ff;">
# Gradient Boosting Regressor:
#     </p>
# </div>

# %%
reg = GradientBoostingRegressor(random_state=42)

# %%
mymodel3 = reg.fit(x_train, y_train)

# %%
mymodel3
# Out:
# GradientBoostingRegressor(random_state=42)

# %%
y_pred3 = reg.predict(x_test)

# %%
rsquared = r2_score(y_test, y_pred3)

# %%
rsquared*100
# Out:
# 87.79726251291787

# %% [markdown]
# <div style="background-color:#4169e1; padding: 1px; border-radius: 15px; box-shadow: 0 2px 4px 0 #f0f8ff;">
#     <p style="font-size:20px; font-family:Calibri, sans-serif; line-height: 1.5em; text-align: justify; text-indent: 20px;color: #f0f8ff;">
# Random Forest:
#     </p>
# </div>

# %%
rf_regressor = RandomForestRegressor(n_estimators=200, random_state=42)

# %%
mymodel4 = rf_regressor.fit(x_train, y_train)

# %%
mymodel4
# Out:
# RandomForestRegressor(n_estimators=200, random_state=42)

# %%
y_pred4 = rf_regressor.predict(x_test)

# %%
rsquared = r2_score(y_test, y_pred4)

# %%
rsquared*100
# Out:
# 86.54750926507404

# %% [markdown]
# <div style="background-color:#4169e1; padding: 1px; border-radius: 15px; box-shadow: 0 2px 4px 0 #f0f8ff;">
#     <p style="font-size:20px; font-family:Calibri, sans-serif; line-height: 1.5em; text-align: justify; text-indent: 20px;color: #f0f8ff;">
# Ridge Model:
#     </p>
# </div>

# %%
ridge_model = Ridge(alpha = 1.0)

# %%
mymodel5 = ridge_model.fit(x_train, y_train)

# %%
mymodel5
# Out:
# Ridge()

# %%
y_pred5 = ridge_model.predict(x_test)

# %%
rsquared = r2_score(y_test, y_pred5)

# %%
rsquared*100
# Out:
# 78.308491263913

# %% [markdown]
# <div style="background-color:#4169e1; padding: 1px; border-radius: 15px; box-shadow: 0 2px 4px 0 #f0f8ff;">
#     <p style="font-size:20px; font-family:Calibri, sans-serif; line-height: 1.5em; text-align: justify; text-indent: 20px;color: #f0f8ff;">
# Conclusion:
#     </p>
# </div>

# %% [markdown]
# <p> Smoking is the greatest factor that affects medical cost charges, then it's bmi and age.</p>
# <p> GradientBoosting Regressor is the model with the highest accuracy</p>

# %%
import pickle

# %%
with open('modella.pkl', 'wb') as f:
    pickle.dump(reg, f)
